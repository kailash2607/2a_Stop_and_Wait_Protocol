# %%
import socket

# Create socket
c = socket.socket()

# Connect to server
c.connect(('localhost', 8000))

while True:
    # Receive message from server
    msg = c.recv(1024).decode()

    print("Server:", msg)

    # Send acknowledgement
    ack = input("Enter acknowledgement: ")

    c.send(ack.encode())
# Out:
# Server: hello
# Enter acknowledgement:  hi
# Server: 1,2,3
# Enter acknowledgement:  5,4
